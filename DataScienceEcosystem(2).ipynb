# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tim Oeser** <br>
# Digitalization Engineer

# %% [markdown]
# *I am interested in Data Science because I want to improve existing manufacturing lines to save ressources and produce more economically and ecologically*

# %% [markdown]
# ### My code analysis your intellect

# %%
print("You are clever :D")
# Out:
# You are clever :D

# %% [markdown]
# + One
# - Two
#
# 1. One
# 2. Two
#
# [Good Translator - Deepl](http://deepl.com)
#
#
#
# Hello | You | There
# --- | --- | ---
# *I* | `like` | **it here**
# You | too | ?

# %% [markdown]
# ### Welcome to the final assesment

# %% [markdown]
# #### Data Science languages
# + Python
# + R
# + Scala

# %% [markdown]
# #### Data Science libraries
# + Tensorflor
# + PyTorch
# + Pandas

# %% [markdown]
# #### Data Science Tools
#
# 1 | 2 | 3
# --- | --- | ---
#  Apache Spark | BigML | IBM Watson Studio

# %% [markdown]
# #### This is a markdown cell which is introducing an arithmetic expression examples

# %%
def multiplication_or_sum(num1, num2):
    product = num1 * num2
    if product <= 100:
        return product
    else:
        return num1 + num2

result = multiplication_or_sum(2,3)
print("The result is = ", result)


result = multiplication_or_sum(500,10)
print("The result is = ", result)
# Out:
# The result is =  6
# The result is =  510

# %%
def convert(minutes):
    minu = 100/(minutes % 60)
    hour = minutes / 60
    print("Time in hours is", (hour+minu))

convert(200)
# Out:
# Time in hours is 8.333333333333334

# %% [markdown]
# #### Markdown cell for a list
# + Objective 1
# + Objective 2

# %% [markdown]
# ## The authors name is Tim Oeser
